# %% [markdown]
# We use thr print() function to output data to the standard output Device(Screen).

# %%
print('We use the print(), function to output data to the standard output Device(Screen).', end='@')
# Out:
# We use the print(), function to output data to the standard output Device(Screen).@

# %% [markdown]
# The input() method read a line from input, converts into a string and returns it.

# %%
input()
# Out:
#  00
# '00'

# %%
var='Hello World'
print(var)
# Out:
# Hello World

# %%
print('My sentense is '+     var)
# Out:
# My sentense is Hello World

# %% [markdown]
# variable

# %%
id(var)
# Out:
# 2256216938864

# %%
import sys
sys.getsizeof(var)
# Out:
# 52
